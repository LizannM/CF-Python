# %% [markdown]
# # Grouping and Aggregating - Spend Type and Order Frequency

# %% [markdown]
# 1. Import Libraries and Dataset
# 2. Mean Orders by Department
# 3. Create a variable for customer spending type
# 4. Create a variable for customer order frequency
# 5. Export data with new variables

# %% [markdown]
# # 01. Import Libraries and Dataset

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\lizan\Desktop\Data Analytics\4.0\31-05-2022 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_busy_loyalty.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2398795        1             2                   3           7
# 2    473747        1             3                   3          12
# 3   2254736        1             4                   4           7
# 4    431534        1             5                   4          15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered  ... aisle_id  department_id  prices  _merge   price_range_loc  \
# 0          0  ...       77              7     9.0    both  Mid Range Produt
# 1          1  ...       77              7     9.0    both  Mid Range Produt
# 2          1  ...       77              7     9.0    both  Mid Range Produt
# 3          1  ...       77              7     9.0    both  Mid Range Produt
# 4          1  ...       77              7     9.0    both  Mid Range Produt
#
#           Busiest_Day  Busiest_Days   Busiest_Hours max_order  loyalty_flag
# 0  Regularly Busy Day  Regular Days  Average Orders        10  New Customer
# 1  Regularly Busy Day  Slowest Days  Average Orders        10  New Customer
# 2  Regularly Busy Day  Slowest Days     Most Orders        10  New Customer
# 3      Least Busy Day  Slowest Days  Average Orders        10  New Customer
# 4      Least Busy Day  Slowest Days     Most Orders        10  New Customer
#
# [5 rows x 21 columns]

# %% [markdown]
# With more data, the mean values charged compared to the subset of on million entries.  A majority decreased, but a couple increased.

# %% [markdown]
# # 03. Customer Type Spending

# %%
# Basic stats for customer spending per product by customer type
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal Customer    10.386336  1.0  99999.0
# New Customer      13.294670  1.0  99999.0
# Regular Customer  12.495717  1.0  99999.0

# %% [markdown]
# On average, Loyal Customers spend less perproduct versus a New or Regular customer.

# %% [markdown]
# Criteria for spending flag
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
#
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge.groupby('user_id').agg({'prices':['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.367797
# 2        7.515897
# 3        8.197727
# 4        8.205556
# 5        9.189189
# ...           ...
# 206205   8.909375
# 206206   7.646667
# 206207   7.313453
# 206208   8.366617
# 206209   7.058915
#
# [206209 rows x 1 columns]

# %%
# Add column for the average spend/product for each user
ords_prods_merge['avg_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2398795        1             2                   3           7
# 2    473747        1             3                   3          12
# 3   2254736        1             4                   4           7
# 4    431534        1             5                   4          15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered  ... department_id  prices  _merge   price_range_loc  \
# 0          0  ...             7     9.0    both  Mid Range Produt
# 1          1  ...             7     9.0    both  Mid Range Produt
# 2          1  ...             7     9.0    both  Mid Range Produt
# 3          1  ...             7     9.0    both  Mid Range Produt
# 4          1  ...             7     9.0    both  Mid Range Produt
#
#           Busiest_Day  Busiest_Days   Busiest_Hours max_order  loyalty_flag  \
# 0  Regularly Busy Day  Regular Days  Average Orders        10  New Customer
# 1  Regularly Busy Day  Slowest Days  Average Orders        10  New Customer
# 2  Regularly Busy Day  Slowest Days     Most Orders        10  New Customer
# 3      Least Busy Day  Slowest Days  Average Orders        10  New Customer
# 4      Least Busy Day  Slowest Days     Most Orders        10  New Customer
#
#    avg_spend
# 0   6.367797
# 1   6.367797
# 2   6.367797
# 3   6.367797
# 4   6.367797
#
# [5 rows x 22 columns]

# %%
# Derive a column for spend type
ords_prods_merge.loc[ords_prods_merge['avg_spend'] < 10, 'spend_type'] = 'Low Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_spend'] >= 10, 'spend_type'] = 'High Spender'

# %%
ords_prods_merge['spend_type'].value_counts(dropna=False)
# Out:
# Low Spender     31770614
# High Spender      634245
# Name: spend_type, dtype: int64

# %%
# Check
ords_prods_merge[['user_id', 'spend_type']].head(80)
# Out:
#     user_id   spend_type
# 0         1  Low Spender
# 1         1  Low Spender
# 2         1  Low Spender
# 3         1  Low Spender
# 4         1  Low Spender
# ..      ...          ...
# 75      120  Low Spender
# 76      120  Low Spender
# 77      185  Low Spender
# 78      195  Low Spender
# 79      195  Low Spender
#
# [80 rows x 2 columns]

# %% [markdown]
# # 04. Customer Order Frequency

# %%
# Add column to customer median order frequency
ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2398795        1             2                   3           7
# 2    473747        1             3                   3          12
# 3   2254736        1             4                   4           7
# 4    431534        1             5                   4          15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered  ... _merge   price_range_loc         Busiest_Day  Busiest_Days  \
# 0          0  ...   both  Mid Range Produt  Regularly Busy Day  Regular Days
# 1          1  ...   both  Mid Range Produt  Regularly Busy Day  Slowest Days
# 2          1  ...   both  Mid Range Produt  Regularly Busy Day  Slowest Days
# 3          1  ...   both  Mid Range Produt      Least Busy Day  Slowest Days
# 4          1  ...   both  Mid Range Produt      Least Busy Day  Slowest Days
#
#     Busiest_Hours max_order  loyalty_flag avg_spend   spend_type  \
# 0  Average Orders        10  New Customer  6.367797  Low Spender
# 1  Average Orders        10  New Customer  6.367797  Low Spender
# 2     Most Orders        10  New Customer  6.367797  Low Spender
# 3  Average Orders        10  New Customer  6.367797  Low Spender
# 4     Most Orders        10  New Customer  6.367797  Low Spender
#
#    median_order_frequency
# 0                    20.5
# 1                    20.5
# 2                    20.5
# 3                    20.5
# 4                    20.5
#
# [5 rows x 24 columns]

# %% [markdown]
# Derive Column for Frequency on the following criteria:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'frequency_flag'] = 'Non-Frequent Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] > 10) & (ords_prods_merge['median_order_frequency'] <= 20), 'frequency_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent Customer        21559853
# Regular Customer          7208564
# Non-Frequent Customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
# Check
ords_prods_merge[['user_id', 'frequency_flag', 'median_order_frequency']].head(60)
# Out:
#     user_id         frequency_flag  median_order_frequency
# 0         1  Non-Frequent Customer                    20.5
# 1         1  Non-Frequent Customer                    20.5
# 2         1  Non-Frequent Customer                    20.5
# 3         1  Non-Frequent Customer                    20.5
# 4         1  Non-Frequent Customer                    20.5
# 5         1  Non-Frequent Customer                    20.5
# 6         1  Non-Frequent Customer                    20.5
# 7         1  Non-Frequent Customer                    20.5
# 8         1  Non-Frequent Customer                    20.5
# 9         1  Non-Frequent Customer                    20.5
# 10       15      Frequent Customer                    10.0
# 11       15      Frequent Customer                    10.0
# 12       15      Frequent Customer                    10.0
# 13       15      Frequent Customer                    10.0
# 14       15      Frequent Customer                    10.0
# 15       19      Frequent Customer                     6.0
# 16       19      Frequent Customer                     6.0
# 17       19      Frequent Customer                     6.0
# 18       21      Frequent Customer                     7.5
# 19       31      Frequent Customer                     6.0
# 20       31      Frequent Customer                     6.0
# 21       43      Frequent Customer                    10.0
# 22       43      Frequent Customer                    10.0
# 23       52      Frequent Customer                     8.0
# 24       52      Frequent Customer                     8.0
# 25       52      Frequent Customer                     8.0
# 26       52      Frequent Customer                     8.0
# 27       52      Frequent Customer                     8.0
# 28       52      Frequent Customer                     8.0
# 29       52      Frequent Customer                     8.0
# 30       52      Frequent Customer                     8.0
# 31       52      Frequent Customer                     8.0
# 32       52      Frequent Customer                     8.0
# 33       52      Frequent Customer                     8.0
# 34       52      Frequent Customer                     8.0
# 35       52      Frequent Customer                     8.0
# 36       52      Frequent Customer                     8.0
# 37       67      Frequent Customer                     7.0
# 38       67      Frequent Customer                     7.0
# 39       67      Frequent Customer                     7.0
# 40       67      Frequent Customer                     7.0
# 41       67      Frequent Customer                     7.0
# 42       67      Frequent Customer                     7.0
# 43       67      Frequent Customer                     7.0
# 44       67      Frequent Customer                     7.0
# 45       67      Frequent Customer                     7.0
# 46       67      Frequent Customer                     7.0
# 47       67      Frequent Customer                     7.0
# 48       67      Frequent Customer                     7.0
# 49       67      Frequent Customer                     7.0
# 50       67      Frequent Customer                     7.0
# 51       67      Frequent Customer                     7.0
# 52       67      Frequent Customer                     7.0
# 53       67      Frequent Customer                     7.0
# 54       67      Frequent Customer                     7.0
# 55       67      Frequent Customer                     7.0
# 56       81  Non-Frequent Customer                    30.0
# 57       81  Non-Frequent Customer                    30.0
# 58       82       Regular Customer                    11.5
# 59       82       Regular Customer                    11.5

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_time', 'days_since_prior_order', 'new_customer', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'Busiest_Day',
#        'Busiest_Days', 'Busiest_Hours', 'max_order', 'loyalty_flag',
#        'avg_spend', 'spend_type', 'median_order_frequency', 'frequency_flag'],
#       dtype='object')

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %% [markdown]
# #  05. Export

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_spend_freq2.pkl'))
